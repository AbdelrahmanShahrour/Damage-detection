# %%
import shahrourdetectron
import skimage.io as io
im1 = io.imread("data/test/60.jpg")
im2 = io.imread("data/test/66.jpg")
im3 = io.imread("data/test/11.jpg")

# %%
shahrourdetectron.img_damage(im1)
# Out:
# Damaged Parts: ['front_bumper']

# %%
shahrourdetectron.img_damage(im2)
# Out:
# Damaged Parts: ['door']

# %%
shahrourdetectron.img_damage(im3)
# Out:
# Damaged Parts: ['door']
